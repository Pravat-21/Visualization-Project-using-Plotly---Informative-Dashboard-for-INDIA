# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("../census_data/final_df.csv")

# %%
df.sample()
# Out:
#           State        District   Latitude  Longitude  District code  \
# 424  Tamil Nadu  Tiruvannamalai  12.419319  79.232656            606
#
#      Population     Male   Female  Literate  Male_Literate  ...  \
# 424     2464875  1235889  1228986   1626813         909803  ...
#
#      Household_size_9_persons_and_above_Households  \
# 424                                           9408
#
#      Location_of_drinking_water_source_Away_Households  \
# 424                                              33865
#
#      Married_couples_1_Households  Married_couples_2_Households  \
# 424                        422698                         77068
#
#      Married_couples_3_Households  Married_couples_3_or_more_Households  \
# 424                          8445                                  9562
#
#      Married_couples_4_Households  Married_couples_5__Households  \
# 424                           968                            149
#
# ...

# %%
df.drop(columns=['Main_Workers', 'Marginal_Workers', 'Non_Workers', 'Cultivator_Workers',
       'Agricultural_Workers', 'Household_Workers', 'Other_Workers','Male_SC', 'Female_SC', 'Male_ST',
       'Female_ST'],inplace=True)

# %%
df.drop(columns=['Others_Religions'],inplace=True)

# %%
df.drop(columns=['LPG_or_PNG_Households'],inplace=True)

# %%
df[['State', 'District','Population','Literate', 'Male_Literate',
       'Female_Literate','Below_Primary_Education', 'Primary_Education',
       'Middle_Education', 'Secondary_Education', 'Higher_Education',
       'Graduate_Education', 'Other_Education', 'Literate_Education',
       'Illiterate_Education', 'Total_Education',]]
# Out:
#               State        District  Population  Literate  Male_Literate  \
# 0    Andhra Pradesh        Adilabad     2741239   1483347         856350
# 1    Andhra Pradesh       Anantapur     4081148   2310960        1338474
# 2    Andhra Pradesh        Chittoor     4174064   2667878        1484794
# 3    Andhra Pradesh   East Godavari     5154296   3288577        1716933
# 4    Andhra Pradesh          Guntur     4887813   2960441        1634726
# ..              ...             ...         ...       ...            ...
# 512     West Bengal          Maldah     3988845   2086432        1152019
# 513     West Bengal     Murshidabad     7103807   4055834        2177187
# 514     West Bengal           Nadia     5167600   3480555        1878866
# 515     West Bengal        Puruliya     2930115   1624905        1002058
# 516     West Bengal  Uttar Dinajpur     3007134   1489667         853495
#
#      Female_Literate  Below_Primary_Education  Primary_Education  \
# ...

# %%
df.shape
# Out:
# (517, 62)

# %%
df.to_csv("../census_data/final_df.csv",index=False)

# %%
pd.read_csv("../census_data/final_df.csv")
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Male_Literate  ...  \
# ...

# %%
df[df['State']=='West Bengal']['District'].unique().tolist()
# Out:
# ['Bankura',
#  'Barddhaman',
#  'Birbhum',
#  'Dakshin Dinajpur',
#  'Darjiling',
#  'Haora',
#  'Hugli',
#  'Jalpaiguri',
#  'Kolkata',
#  'Maldah',
#  'Murshidabad',
#  'Nadia',
#  'Puruliya',
#  'Uttar Dinajpur']

# %%
df.columns
# Out:
# Index(['State', 'District', 'Latitude', 'Longitude', 'District code',
#        'Population', 'Male', 'Female', 'Literate', 'Male_Literate',
#        'Female_Literate', 'SC', 'ST', 'Workers', 'Male_Workers',
#        'Female_Workers', 'Hindus', 'Muslims', 'Christians', 'Sikhs',
#        'Buddhists', 'Jains', 'Housholds_with_Electric_Lighting',
#        'Households_with_Internet', 'Households_with_Computer',
#        'Rural_Households', 'Urban_Households', 'Households',
#        'Below_Primary_Education', 'Primary_Education', 'Middle_Education',
#        'Secondary_Education', 'Higher_Education', 'Graduate_Education',
#        'Other_Education', 'Literate_Education', 'Illiterate_Education',
#        'Total_Education', 'Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50',
#        'Households_with_Television', 'Ownership_Owned_Households',
#        'Ownership_Rented_Households', 'Household_size_1_person_Households',
# ...

# %%
df[['District','District code']]
# Out:
#            District  District code
# 0          Adilabad            532
# 1         Anantapur            553
# 2          Chittoor            554
# 3     East Godavari            545
# 4            Guntur            548
# ..              ...            ...
# 512          Maldah            332
# 513     Murshidabad            333
# 514           Nadia            336
# 515        Puruliya            340
# 516  Uttar Dinajpur            330
#
# [517 rows x 2 columns]

# %%
df['District']=df['District'] +"("+ df['District code'].astype('str')+ ")"

# %%
df
# Out:
#               State             District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad(532)  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur(553)  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor(554)  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari(545)  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur(548)  15.884926  80.586576            548
# ..              ...                  ...        ...        ...            ...
# 512     West Bengal          Maldah(332)  25.080268  88.171917            332
# 513     West Bengal     Murshidabad(333)  24.259507  88.168169            333
# 514     West Bengal           Nadia(336)  23.564110  88.582930            336
# 515     West Bengal        Puruliya(340)  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur(330)  26.044619  88.235952            330
#
# ...

# %%
df.head(4)
# Out:
#             State            District   Latitude  Longitude  District code  \
# 0  Andhra Pradesh       Adilabad(532)  19.284514  78.813212            532
# 1  Andhra Pradesh      Anantapur(553)  14.312066  77.460158            553
# 2  Andhra Pradesh       Chittoor(554)  13.331093  78.927639            554
# 3  Andhra Pradesh  East Godavari(545)  16.782718  82.243207            545
#
#    Population     Male   Female  Literate  Male_Literate  ...  \
# 0     2741239  1369597  1371642   1483347         856350  ...
# 1     4081148  2064495  2016653   2310960        1338474  ...
# 2     4174064  2090204  2083860   2667878        1484794  ...
# 3     5154296  2569688  2584608   3288577        1716933  ...
#
#    Household_size_9_persons_and_above_Households  \
# 0                                          12000
# 1                                          20566
# 2                                          13905
# 3                                           7478
#
# ...

# %%
df["Sex_ratio"] = round((df['Female']/df['Male'])*100,2)

# %%
temp =df[['State','District','Sex_ratio']].sort_values(by='Sex_ratio',ascending=False).head(10)

# %%
px.bar(data_frame=temp,x='District',y='Sex_ratio',color='State')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
# ...

# %% [markdown]
# 'Literate_Education', 'Illiterate_Education'

# %%
df['Illiterate_ratio'] = round((df['Illiterate_Education']/df['Literate_Education'])*100,2)

# %%
df[['State','District',
'Hindus', 'Muslims', 'Christians', 'Sikhs',
       'Buddhists', 'Jains',]]
# Out:
#               State             District   Hindus  Muslims  Christians  Sikhs  \
# 0    Andhra Pradesh        Adilabad(532)  2399901   275970       15422   1377
# 1    Andhra Pradesh       Anantapur(553)  3599372   443456       20463    932
# 2    Andhra Pradesh        Chittoor(554)  3737588   397870       24129    867
# 3    Andhra Pradesh   East Godavari(545)  4983330    77777       77825    738
# 4    Andhra Pradesh          Guntur(548)  4217597   559770       89763    764
# ..              ...                  ...      ...      ...         ...    ...
# 512     West Bengal          Maldah(332)  1914352  2045151       13209    747
# 513     West Bengal     Murshidabad(333)  2359061  4707573       18102    766
# 514     West Bengal           Nadia(336)  3728482  1382682       33835    849
# 515     West Bengal        Puruliya(340)  2373120   227249        8646    622
# 516     West Bengal  Uttar Dinajpur(330)  1482943  1501170       16702    477
#
#      Buddhists  Jains
# ...

# %%
temp_df = df[[
'Hindus', 'Muslims', 'Christians', 'Sikhs',
       'Buddhists', 'Jains',]].sum().reset_index()

# %%
temp_df.columns = ['Religion', 'Population']

# %%
temp_df
# Out:
#      Religion  Population
# 0      Hindus   821271348
# 1     Muslims   139317340
# 2  Christians    22971390
# 3       Sikhs    17597026
# 4   Buddhists     7675527
# 5       Jains     3616195

# %%
px.pie(data_frame=temp_df, values='Population',names='Religion',color_discrete_sequence=px.colors.qualitative.Pastel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
# ...

# %%
age = df[['Age_Group_0_29', 'Age_Group_30_49', 'Age_Group_50']]

# %%
age.rename(columns={'Age_Group_0_29':'Below 29','Age_Group_30_49':'Between 30-49','Age_Group_50':'More than 50'},inplace=True)

# %%
age = age.sum().reset_index()

# %%
age.columns=['Age_group','Pop']

# %%
age
# Out:
#        Age_group        Pop
# 0       Below 29  596901010
# 1  Between 30-29  257582112
# 2   More than 50  161715380

# %%
px.bar(data_frame=age, x='Age_group',y='Pop',color_discrete_sequence=px.colors.qualitative.Pastel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
# ...

# %%
df
# Out:
#               State             District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad(532)  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur(553)  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor(554)  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari(545)  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur(548)  15.884926  80.586576            548
# ..              ...                  ...        ...        ...            ...
# 512     West Bengal          Maldah(332)  25.080268  88.171917            332
# 513     West Bengal     Murshidabad(333)  24.259507  88.168169            333
# 514     West Bengal           Nadia(336)  23.564110  88.582930            336
# 515     West Bengal        Puruliya(340)  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur(330)  26.044619  88.235952            330
#
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
df = pd.read_csv("../census_data/final_df.csv")

# %%
df[['Housholds_with_Electric_Lighting',
       'Households_with_Internet', 'Households_with_Computer',
       'Rural_Households', 'Urban_Households', 'Households','Households_with_Television', 'Ownership_Owned_Households',
       'Ownership_Rented_Households']]
# Out:
#      Housholds_with_Electric_Lighting  Households_with_Internet  \
# 0                              566108                      5512
# 1                              897970                      8606
# 2                              944555                     13763
# 3                             1297273                     22411
# 4                             1186028                     19383
# ..                                ...                       ...
# 512                            297716                      5357
# 513                            541169                      7951
# 514                            623729                     12787
# 515                            189889                      3551
# 516                            199307                      2883
#
#      Households_with_Computer  Rural_Households  Urban_Households  Households  \
# 0                       45202            597466            220248      817714
# ...

# %%
temp = df.groupby(by=['State','District'])[['Housholds_with_Electric_Lighting',
       'Households_with_Internet', 'Households_with_Computer',
       'Rural_Households', 'Urban_Households', 'Households','Households_with_Television', 'Ownership_Owned_Households',
       'Ownership_Rented_Households']].sum().reset_index()

# %%
temp.rename(columns={"Housholds_with_Electric_Lighting":"With Electrcity",
                    "Households_with_Internet":"With Internet",
                    "Households_with_Computer":"With Computers",
                    "Rural_Households": "Rural Households",
                    "Urban_Households":"Urban Households",	
                    "Households":"Total Households",
                    "Households_with_Television":"With Television",
                    "Ownership_Owned_Households":"Owned Households",
                    "Ownership_Rented_Households":"Rented Households"},inplace=True)

# %%
temp_df = temp[temp['State']=='West Bengal']

# %%
temp_df
# Out:
#            State          District  With Electrcity  With Internet  \
# 493  West Bengal           Bankura           334670           4273
# 494  West Bengal        Barddhaman          1049943          32323
# 495  West Bengal           Birbhum           333752           5210
# 496  West Bengal  Dakshin Dinajpur           168069           2518
# 497  West Bengal         Darjiling           297176          10943
# 498  West Bengal             Haora           796953          30751
# 499  West Bengal             Hugli           965258          31725
# 500  West Bengal        Jalpaiguri           382500           9322
# 501  West Bengal           Kolkata           927602         136618
# 502  West Bengal            Maldah           297716           5357
# 503  West Bengal       Murshidabad           541169           7951
# 504  West Bengal             Nadia           623729          12787
# 505  West Bengal          Puruliya           189889           3551
# ...

# %%
import plotly.express as px

# %%
px.bar(data_frame=temp_df,x='District',y=['Housholds_with_Electric_Lighting','Households_with_Internet','Households_with_Television','Households_with_Computer'],barmode='group',log_y=True,text_auto=True
       ,labels={
           'variable':'Facility',
           'value':'Total households',
           

       })
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
# ...

# %%
rural_urb = temp_df[['Rural_Households','Urban_Households']].sum().reset_index()

# %%
rural_urb
# Out:
#               index         0
# 0  Rural_Households  10814472
# 1  Urban_Households   5660037

# %%
rural_urb.columns = ['Type','Pop']

# %%
rural_urb
# Out:
#                Type       Pop
# 0  Rural_Households  10814472
# 1  Urban_Households   5660037

# %%
px.pie(data_frame=rural_urb, values='Pop',names='Type').update_traces(pull=[0.01, 0.01])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
# ...

# %%
df
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Male_Literate  ...  \
# ...

# %%
top_10_pop = df[df['State']=='Bihar'].sort_values(by=['Population'],ascending=False).head(10)

# %%
top_10_pop
# Out:
#     State            District   Latitude  Longitude  District code  \
# 76  Bihar               Patna  25.402971  85.319843            230
# 77  Bihar     Purba Champaran  26.681293  85.003822            204
# 72  Bihar         Muzaffarpur  26.186644  85.327451            216
# 70  Bihar           Madhubani  26.413805  86.163284            207
# 61  Bihar                Gaya  24.726654  84.942912            236
# 81  Bihar          Samastipur  25.793206  85.948333            221
# 82  Bihar               Saran  25.896561  84.822663            219
# 60  Bihar           Darbhanga  26.146188  85.973874            215
# 75  Bihar  Pashchim Champaran  27.160644  84.302659            203
# 54  Bihar          Aurangabad  24.774292  84.459860            515
#
#     Population     Male   Female  Literate  Male_Literate  ...  \
# 76     5838465  3078512  2759953   3459679        2028047  ...
# 77     5099371  2681209  2418162   2276957        1407603  ...
# ...

# %%
temp_df = df[df['State']=='Bihar']

# %%
temp_df[['Ownership_Owned_Households',
       'Ownership_Rented_Households']].sum()
# Out:
# Ownership_Owned_Households     18557842
# Ownership_Rented_Households      530671
# dtype: int64

# %%
male_fe = df[df['District']=='Kolkata'][['Male','Female']].sum().reset_index()

# %%
male_fe.columns = ['Sex','Pop']

# %%
male_fe
# Out:
#       Sex      Pop
# 0    Male  2356766
# 1  Female  2139928

# %%
kol = df[df['District']=='Kolkata']

# %%
temp = kol[['Below_Primary_Education', 'Primary_Education', 'Middle_Education',
       'Secondary_Education', 'Higher_Education', 'Graduate_Education',
       'Other_Education']].rename(columns={
           'Below_Primary_Education':"Below Primary", 
           'Primary_Education':"Primary", 
           'Middle_Education':"Middle Education",
       'Secondary_Education':"Secondary Education", 
       'Higher_Education':"Higher Education", 
       'Graduate_Education':"Graduate Education",
       'Other_Education':"Other Education"
       }).melt()

# %%
temp
# Out:
#               variable   value
# 0        Below Primary  255171
# 1              Primary  597841
# 2     Middle Education  820902
# 3  Secondary Education  555529
# 4     Higher Education  425245
# 5   Graduate Education  691804
# 6      Other Education   89701

# %%
px.histogram(data_frame=temp,x='variable',y='value')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\IPython\core\formatters.py:984, in IPythonDisplayFormatter.__call__(self, obj)
#     982 method = get_real_method(obj, self.print_method)
#     983 if method is not None:
# --> 984     method()
#     985     return True
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\basedatatypes.py:850, in BaseFigure._ipython_display_(self)
#     847 import plotly.io as pio
#     849 if pio.renderers.render_on_display and pio.renderers.default:
# --> 850     pio.show(self)
#     851 else:
#     852     print(repr(self))
#
# File e:\DATA SCIENCE & AI\PROJECTS\Data Visualization with Python\.venv\Lib\site-packages\plotly\io\_renderers.py:415, in show(fig, renderer, validate, **kwargs)
# ...

# %%
import pandas as pd
df = pd.read_csv("../census_data/final_df.csv")

# %%
df.sample(3)
# Out:
#               State    District   Latitude  Longitude  District code  \
# 188       Karnataka     Belgaum  16.161072  74.723290            555
# 471   Uttar Pradesh  Kushinagar  26.892531  83.922615            189
# 258  Madhya Pradesh       Seoni  22.332305  79.660539            456
#
#      Population     Male   Female  Literate  Male_Literate  ...  \
# 188     4779661  2423063  2356598   3052032        1725548  ...
# 471     3564544  1818055  1746489   1954820        1183722  ...
# 258     1379131   695879   683252    864194         485341  ...
#
#      Household_size_9_persons_and_above_Households  \
# 188                                          66120
# 471                                         104073
# 258                                           6135
#
#      Location_of_drinking_water_source_Away_Households  \
# 188                                             231175
# 471                                              40527
# ...

# %%
temp = df[df['District']=='Kolkata']

# %%
size = temp[['Household_size_1_person_Households',
       'Household_size_2_persons_Households', 'Household_size_1_to_2_persons',
       'Household_size_3_persons_Households',
       'Household_size_3_to_5_persons_Households',
       'Household_size_4_persons_Households',
       'Household_size_5_persons_Households',
       'Household_size_6_8_persons_Households',
       'Household_size_9_persons_and_above_Households']].rename(columns={
        'Household_size_1_person_Households':"Size-1",
       'Household_size_2_persons_Households':"Size-2", 'Household_size_1_to_2_persons':"Size-(1-2)",
       'Household_size_3_persons_Households':"Size-3",
       'Household_size_3_to_5_persons_Households':"Size-(3-5)",
       'Household_size_4_persons_Households':"Size-4",
       'Household_size_5_persons_Households':"Size-5",
       'Household_size_6_8_persons_Households':"Size-(6-8)",
       'Household_size_9_persons_and_above_Households':"Size-9+"
       }).melt()

# %%
size.rename(columns={
    'variable':'Size of Household',
    'value':'Population'
},inplace=True)

# %%
size
# Out:
#   Size of Household  Population
# 0            Size-1       50120
# 1            Size-2      121054
# 2        Size-(1-2)      171174
# 3            Size-3      227976
# 4        Size-(3-5)      590949
# 5            Size-4      224157
# 6            Size-5      138816
# 7        Size-(6-8)      158092
# 8           Size-9+       43968

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
px.bar(data_frame=size, x='Size of Household',y='Population',text_auto=True)
